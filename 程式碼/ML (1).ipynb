# %%
import pandas as pd

# %%
data2 = pd.read_csv('/content/drive/MyDrive/mldata.csv')

# %%
data2.tail(45)
# Out:
#         ID    ROA  ...  Total asset turnover  After-tax net profit growth rate
# 954   9938   5.97  ...                  0.49                              6.16
# 955   9939   4.32  ...                  0.61                             18.01
# 956   9940   4.89  ...                  0.41                             22.96
# 957   9941   1.51  ...                  0.15                             -5.36
# 958   9942   9.01  ...                  0.67                             -5.44
# 959   9943  10.32  ...                  0.45                            -19.26
# 960   9944   1.14  ...                  0.46                            325.81
# 961   9945  20.81  ...                  0.11                             -3.24
# 962   9946   1.70  ...                  0.13                            -88.48
# 963   9955  -4.22  ...                  1.03                          -1310.51
# 964   9958   8.53  ...                  0.45                             69.45
# ...

# %% [markdown]
# # 資料清整

# %%
#清整後資料
data3=data2[0:965]

# %%
data3.describe()
# Out:
#               ROA  ...  After-tax net profit growth rate
# count  964.000000  ...                        964.000000
# mean     4.492085  ...                        140.177459
# std      8.911582  ...                       1532.311070
# min    -55.100000  ...                     -13124.010000
# 25%      0.725000  ...                        -26.670000
# 50%      3.990000  ...                         10.280000
# 75%      7.700000  ...                         71.747500
# max     76.710000  ...                      23853.740000
#
# [8 rows x 6 columns]

# %%
data3.loc[0]
# Out:
# ID                                        1101
# ROA                                       6.74
# ROE                                      11.93
# Operating gross profit margin            32.87
# cash flow                           25,091,819
# Debt ratio                               43.82
# Total asset turnover                       0.3
# After-tax net profit growth rate          9.96
# Name: 0, dtype: object

# %% [markdown]
# # Data Preprocessing

# %%
#/content/drive/MyDrive/mldata.csv
data3
# Out:
#        ID    ROA  ...  Total asset turnover  After-tax net profit growth rate
# 0    1101   6.74  ...                  0.30                              9.96
# 1    1102   5.92  ...                  0.27                            -15.60
# 2    1103   5.39  ...                  0.05                             30.48
# 3    1104   5.64  ...                  0.23                             10.35
# 4    1108   5.17  ...                  0.59                            754.54
# ..    ...    ...  ...                   ...                               ...
# 960  9944   1.14  ...                  0.46                            325.81
# 961  9945  20.81  ...                  0.11                             -3.24
# 962  9946   1.70  ...                  0.13                            -88.48
# 963  9955  -4.22  ...                  1.03                          -1310.51
# 964  9958   8.53  ...                  0.45                             69.45
#
# [965 rows x 8 columns]

# %%
#data3.to_csv('/content/drive/MyDrive/mldata.csv')

# %%
import pandas as pd

# %%
R=pd.read_csv('/content/drive/MyDrive/mldata.csv')

# %%
R
# Out:
#         ID   ROA  ...  Total asset turnover  After-tax net profit growth rate
# 0     1101  6.74  ...                  0.30                              9.96
# 1     1102  5.92  ...                  0.27                            -15.60
# 2     1103  5.39  ...                  0.05                             30.48
# 3     1104  5.64  ...                  0.23                             10.35
# 4     1108  5.17  ...                  0.59                            754.54
# ..     ...   ...  ...                   ...                               ...
# 994  M9900  6.09  ...                  0.45                             -8.59
# 995  Y5555  1.52  ...                  0.11                              5.49
# 996  Y8886  4.00  ...                  0.50                              6.24
# 997  Y8888  5.67  ...                  0.84                             27.49
# 998  Y9999  2.52  ...                  0.30                             22.18
#
# [999 rows x 8 columns]

# %% [markdown]
# # 資料總覽、敘述統計

# %%
data3.describe()
# Out:
#               ROA  ...  After-tax net profit growth rate
# count  932.000000  ...                        932.000000
# mean     4.600762  ...                        145.094925
# std      9.040147  ...                       1558.179178
# min    -55.100000  ...                     -13124.010000
# 25%      0.865000  ...                        -26.760000
# 50%      4.190000  ...                         11.580000
# 75%      7.940000  ...                         76.995000
# max     76.710000  ...                      23853.740000
#
# [8 rows x 6 columns]

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                965 non-null    object
#  1   ROA                               964 non-null    float64
#  2   ROE                               964 non-null    float64
#  3   Operating gross profit margin     939 non-null    float64
#  4   cash flow                         932 non-null    object
#  5   Debt ratio                        965 non-null    float64
#  6   Total asset turnover              939 non-null    float64
#  7   After-tax net profit growth rate  964 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 60.4+ KB

# %% [markdown]
# # 檢查空值

# %%
data3.isnull()
# Out:
#         ID    ROA  ...  Total asset turnover  After-tax net profit growth rate
# 0    False  False  ...                 False                             False
# 1    False  False  ...                 False                             False
# 2    False  False  ...                 False                             False
# 3    False  False  ...                 False                             False
# 4    False  False  ...                 False                             False
# ..     ...    ...  ...                   ...                               ...
# 960  False  False  ...                 False                             False
# 961  False  False  ...                 False                             False
# 962  False  False  ...                 False                             False
# 963  False  False  ...                 False                             False
# 964  False  False  ...                 False                             False
#
# [965 rows x 8 columns]

# %% [markdown]
# ## 去空值

# %%
# 
data3=data3.dropna()

# %% [markdown]
# # 檢查重複值

# %%
data3.drop_duplicates()
# Out:
#        ID    ROA  ...  Total asset turnover  After-tax net profit growth rate
# 0    1101   6.74  ...                  0.30                              9.96
# 1    1102   5.92  ...                  0.27                            -15.60
# 2    1103   5.39  ...                  0.05                             30.48
# 3    1104   5.64  ...                  0.23                             10.35
# 4    1108   5.17  ...                  0.59                            754.54
# ..    ...    ...  ...                   ...                               ...
# 960  9944   1.14  ...                  0.46                            325.81
# 961  9945  20.81  ...                  0.11                             -3.24
# 962  9946   1.70  ...                  0.13                            -88.48
# 963  9955  -4.22  ...                  1.03                          -1310.51
# 964  9958   8.53  ...                  0.45                             69.45
#
# [932 rows x 8 columns]

# %%
data3['After-tax net profit growth rate'].iloc[259]
# Out:
# 4.5

# %%
data3['After-tax net profit growth rate'].describe()
# Out:
# count      932.000000
# mean       145.094925
# std       1558.179178
# min     -13124.010000
# 25%        -26.760000
# 50%         11.580000
# 75%         76.995000
# max      23853.740000
# Name: After-tax net profit growth rate, dtype: float64

# %% [markdown]
# ## 建立Class(growth)

# %%
data3['Growth_CLass']=0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data3['Growth_CLass']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 960    0
# 961    0
# 962    0
# 963    0
# 964    0
# Name: Growth_CLass, Length: 932, dtype: int64

# %%
for i in range(0,932):
    if -26.760000>data3['After-tax net profit growth rate'].iloc[i]>-13124.010000:
        #25%-min
        data3['Growth_CLass'].iloc[i]=0
    elif 11.580000>data3['After-tax net profit growth rate'].iloc[i]>-26.760000:
        #50%-25%
        data3['Growth_CLass'].iloc[i]=1
    elif 76.995000>data3['After-tax net profit growth rate'].iloc[i]>11.580000:
        #75%-50%
        data3['Growth_CLass'].iloc[i]=2
    elif 23853.740000>data3['After-tax net profit growth rate'].iloc[i]>76.995000:
        #max-75%
        data3['Growth_CLass'].iloc[i]=3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
data3
# Out:
#        ID    ROA  ...  After-tax net profit growth rate  Growth_CLass
# 0    1101   6.74  ...                              9.96             1
# 1    1102   5.92  ...                            -15.60             1
# 2    1103   5.39  ...                             30.48             2
# 3    1104   5.64  ...                             10.35             1
# 4    1108   5.17  ...                            754.54             3
# ..    ...    ...  ...                               ...           ...
# 960  9944   1.14  ...                            325.81             3
# 961  9945  20.81  ...                             -3.24             1
# 962  9946   1.70  ...                            -88.48             0
# 963  9955  -4.22  ...                          -1310.51             0
# 964  9958   8.53  ...                             69.45             2
#
# [932 rows x 9 columns]

# %%
data3.to_csv('/content/drive/MyDrive/mldata_not_yet_standardized.csv')

# %% [markdown]
# ## 標準後的檔案做成長率類別

# %%
df_std['Growth_CLass']=0
# 先建立Growth_CLass欄位並預設為零

# %%
for i in range(0,932):
    if -26.760000>data3['After-tax net profit growth rate'].iloc[i]>-13124.010000:
        #25%-min
        df_std['Growth_CLass'].iloc[i]=0
    elif 11.580000>data3['After-tax net profit growth rate'].iloc[i]>-26.760000:
        #50%-25%
        df_std['Growth_CLass'].iloc[i]=1
    elif 76.995000>data3['After-tax net profit growth rate'].iloc[i]>11.580000:
        #75%-50%
        df_std['Growth_CLass'].iloc[i]=2
    elif 23853.740000>data3['After-tax net profit growth rate'].iloc[i]>76.995000:
        #max-75%
        df_std['Growth_CLass'].iloc[i]=3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data3['After-tax net profit growth rate'].iloc[0:10]
# Out:
# 0      9.96
# 1    -15.60
# 2     30.48
# 3     10.35
# 4    754.54
# 5     -0.67
# 6    -49.01
# 7    -60.31
# 8     -3.28
# 9     36.93
# Name: After-tax net profit growth rate, dtype: float64

# %%
df_std['Growth_CLass'].iloc[0:10]
# Out:
# 0    1
# 1    1
# 2    2
# 3    1
# 4    3
# 5    1
# 6    0
# 7    0
# 8    1
# 9    2
# Name: Growth_CLass, dtype: int64

# %%
df_std.to_csv('/content/drive/MyDrive/mldata_standardized_with_gclass.csv')

# %% [markdown]
# # 標準化（因為資料scale大)

# %%
#,'cash flow','Debt ratio','Total asset turnover']
data3[['ROA','ROE','Operating gross profit margin','cash flow','Debt ratio','Total asset turnover']]
#,['Operating gross profit margin']
# Out:
#        ROA    ROE  ...  Debt ratio Total asset turnover
# 0     6.74  11.93  ...       43.82                 0.30
# 1     5.92  10.36  ...       42.82                 0.27
# 2     5.39   8.78  ...       38.45                 0.05
# 3     5.64   7.26  ...       22.06                 0.23
# 4     5.17   8.84  ...       41.99                 0.59
# ..     ...    ...  ...         ...                  ...
# 960   1.14   2.00  ...       42.01                 0.46
# 961  20.81  34.27  ...       36.17                 0.11
# 962   1.70   2.88  ...       39.88                 0.13
# 963  -4.22  -7.42  ...       44.85                 1.03
# 964   8.53  16.21  ...       45.74                 0.45
#
# [932 rows x 6 columns]

# %%
data3_for_scale = data3[['ROA','ROE','Operating gross profit margin','cash flow','Debt ratio','Total asset turnover']]

# %%
data3_for_scale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 932 entries, 0 to 964
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ROA                            932 non-null    float64
#  1   ROE                            932 non-null    float64
#  2   Operating gross profit margin  932 non-null    float64
#  3   cash flow                      932 non-null    object
#  4   Debt ratio                     932 non-null    float64
#  5   Total asset turnover           932 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 51.0+ KB

# %% [markdown]
# ### 清理金錢的逗號區隔符號，並轉成dtype float64

# %%
data3_for_scale["cash flow"].apply(type).value_counts()
# Out:
# <class 'str'>    932
# Name: cash flow, dtype: int64

# %%
def clean_currency(x):
    """ If the value is a string, then remove currency symbol and delimiters
    otherwise, the value is numeric and can be converted
    """
    if isinstance(x, str):
        return(x.replace('$', '').replace(',', ''))
    return(x)

# %%
data3_for_scale["cash flow"]=data3_for_scale["cash flow"].apply(clean_currency).astype('float')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data3_for_scale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 932 entries, 0 to 964
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ROA                            932 non-null    float64
#  1   ROE                            932 non-null    float64
#  2   Operating gross profit margin  932 non-null    float64
#  3   cash flow                      932 non-null    float64
#  4   Debt ratio                     932 non-null    float64
#  5   Total asset turnover           932 non-null    float64
# dtypes: float64(6)
# memory usage: 51.0 KB

# %% [markdown]
# ## StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler().fit(data3_for_scale)
scaler.transform(data3_for_scale)
#scaler
# Out:
# array([[ 0.23676461,  0.16961588,  0.32870802,  3.90170781, -0.0735926 ,
#         -0.79161703],
#        [ 0.14600941,  0.11867402,  0.2195728 ,  1.33125739, -0.1266028 ,
#         -0.84759198],
#        [ 0.08735057,  0.06740769, -0.84989321, -0.20338929, -0.35825737,
#         -1.2580749 ],
#        ...,
#        [-0.32104781, -0.12402987,  0.2210516 , -0.12357868, -0.28245279,
#         -1.10880838],
#        [-0.97625604, -0.45823443, -0.67687396, -0.17955207, -0.0189921 ,
#          0.57043993],
#        [ 0.43487656,  0.30848923,  0.22341767, -0.52301078,  0.02818698,
#         -0.51174232]])

# %%
data3_std_=scaler.transform(data3_for_scale)

# %%
df_std = pd.DataFrame(data3_std_, columns = ['ROA','ROE','Operating gross profit margin','cash flow','Debt ratio','Total asset turnover'])

# %%
df_std
# Out:
#           ROA       ROE  ...  Debt ratio  Total asset turnover
# 0    0.236765  0.169616  ...   -0.073593             -0.791617
# 1    0.146009  0.118674  ...   -0.126603             -0.847592
# 2    0.087351  0.067408  ...   -0.358257             -1.258075
# 3    0.115020  0.018088  ...   -1.227095             -0.922225
# 4    0.063002  0.069355  ...   -0.170601             -0.250526
# ..        ...       ...  ...         ...                   ...
# 927 -0.383027 -0.152583  ...   -0.169541             -0.493084
# 928  1.793991  0.894483  ...   -0.479121             -1.146125
# 929 -0.321048 -0.124030  ...   -0.282453             -1.108808
# 930 -0.976256 -0.458234  ...   -0.018992              0.570440
# 931  0.434877  0.308489  ...    0.028187             -0.511742
#
# [932 rows x 6 columns]

# %%
df_std.to_csv('/content/drive/MyDrive/mldata_CLEAN.csv')

# %%
import seaborn as sns
sns_plot_std=sns.pairplot(df_std)

# %%
df_std.boxplot(rot=45)

# %% [markdown]
# ## Min-Max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler=MinMaxScaler()
min_max_scaler.fit_transform(data3_for_scale)
#data3_minmax
# Out:
# array([[0.46916015, 0.89777065, 0.90775147, 0.48637474, 0.44173718,
#         0.05847953],
#        [0.46293908, 0.89599756, 0.9026656 , 0.37761089, 0.43154246,
#         0.05263158],
#        [0.45891814, 0.89421318, 0.85282686, 0.31267516, 0.38699154,
#         0.00974659],
#        ...,
#        [0.4309233 , 0.88754997, 0.90273451, 0.3160522 , 0.40156999,
#         0.02534113],
#        [0.38601017, 0.8759176 , 0.86088982, 0.31368379, 0.45223774,
#         0.20077973],
#        [0.48274031, 0.9026043 , 0.90284478, 0.29915097, 0.46131104,
#         0.0877193 ]])

# %%
data3_minmax=min_max_scaler.fit_transform(data3_for_scale)

# %%
df = pd.DataFrame(data3_minmax, columns = ['ROA','ROE','Operating gross profit margin','cash flow','Debt ratio','Total asset turnover'])

# %%
df
# Out:
#           ROA       ROE  ...  Debt ratio  Total asset turnover
# 0    0.469160  0.897771  ...    0.441737              0.058480
# 1    0.462939  0.895998  ...    0.431542              0.052632
# 2    0.458918  0.894213  ...    0.386992              0.009747
# 3    0.460815  0.892497  ...    0.219900              0.044834
# 4    0.457249  0.894281  ...    0.423081              0.115010
# ..        ...       ...  ...         ...                   ...
# 927  0.426675  0.886556  ...    0.423285              0.089669
# 928  0.575905  0.923000  ...    0.363748              0.021442
# 929  0.430923  0.887550  ...    0.401570              0.025341
# 930  0.386010  0.875918  ...    0.452238              0.200780
# 931  0.482740  0.902604  ...    0.461311              0.087719
#
# [932 rows x 6 columns]

# %%
#
import seaborn as sns
sns_plot=sns.pairplot(df)

# %% [markdown]
# # PCA

# %%
data3_std_.shape[1]
# Out:
# 6

# %%
data3_std_["cash flow"]=data3_std_["cash flow"].apply(clean_currency).astype('float')

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

# Find the optimal number of PCA 
pca = PCA(n_components=data3_std_.shape[1])
#用六個主成分
pca.fit(data3_std_)
#fit 到 data3_std(經過標準化後的資料)
ratios = pca.explained_variance_ratio_
# 各主成分可以解釋的比率
# Plot the explained variance ratios
x = np.arange(data3_std_.shape[1])
# 生成0~5的 array
plt.plot(x, np.cumsum(ratios), '-o')
#畫出主成分數與可解釋ratio的圖
plt.xlabel("Number of PCA's")
plt.ylabel("Cumulated Sum of Explained Variance")
plt.title("Variance Explained by PCA's")

# Find the optimal number of PCA's
for i in range(np.cumsum(ratios).shape[0]):
  if np.cumsum(ratios)[i] >= 0.99:
      #找最佳的PCA 
    num_pca = i + 1
    print ("The optimal number of PCA's is: {}".format(num_pca))
    break
  else:
    continue
# Out:
# The optimal number of PCA's is: 1

# %%
plt.style.use('seaborn-whitegrid')
df_std.hist(bins=20, figsize=(60,40), color='lightblue', edgecolor = 'red')
plt.show()

# %%
df_std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932 entries, 0 to 931
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ROA                            932 non-null    float64
#  1   ROE                            932 non-null    float64
#  2   Operating gross profit margin  932 non-null    float64
#  3   cash flow                      932 non-null    float64
#  4   Debt ratio                     932 non-null    float64
#  5   Total asset turnover           932 non-null    float64
# dtypes: float64(6)
# memory usage: 43.8 KB

# %%
import pandas as pd
data3_std_ = pd.read_csv('/content/drive/MyDrive/mldata_not_yet_standardized.csv')

# %%
data3_std_
# Out:
#      Unnamed: 0    ID  ...  After-tax net profit growth rate  Growth_CLass
# 0             0  1101  ...                              9.96             1
# 1             1  1102  ...                            -15.60             1
# 2             2  1103  ...                             30.48             2
# 3             3  1104  ...                             10.35             1
# 4             4  1108  ...                            754.54             3
# ..          ...   ...  ...                               ...           ...
# 927         960  9944  ...                            325.81             3
# 928         961  9945  ...                             -3.24             1
# 929         962  9946  ...                            -88.48             0
# 930         963  9955  ...                          -1310.51             0
# 931         964  9958  ...                             69.45             2
#
# [932 rows x 10 columns]

# %%
data3_std_.Growth_CLass

# %%
import plotly.express as px
n_components = 2
from sklearn.decomposition import PCA
#pca = PCA(n_components=n_components)
#components = pca.fit_transform(df)
# Find the optimal number of PCA 
pca = PCA(n_components=n_components)
#用六個主成分
components = pca.fit_transform(X)
#pca.fit(data3_std_)
total_var = pca.explained_variance_ratio_.sum() * 100

labels = {str(i): f"PC {i+1}" for i in range(n_components)}
labels['color'] = 'Median Price'

fig = px.scatter_matrix(
    components,
    color=y,
    dimensions=range(n_components),
    labels=labels,
    title=f'Total Explained Variance: {total_var:.2f}%',
)
fig.update_traces(diagonal_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b5d3f76f-b2dd-46d9-aef4-89fa666e8044" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5d3f76f-b2dd-46d9-aef4-89fa666e8044")) {
#                     Plotly.newPlot(
#                         'b5d3f76f-b2dd-46d9-aef4-89fa666e8044',
# ...

# %% [markdown]
# ## 新增區段

# %%
df_std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932 entries, 0 to 931
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ROA                            932 non-null    float64
#  1   ROE                            932 non-null    float64
#  2   Operating gross profit margin  932 non-null    float64
#  3   cash flow                      932 non-null    float64
#  4   Debt ratio                     932 non-null    float64
#  5   Total asset turnover           932 non-null    float64
# dtypes: float64(6)
# memory usage: 43.8 KB

# %%
sns.displot(df_std,x='ROA',kde=True)

# %%
import plotly.express as px
#df_std = px.data.tips()
fig = px.histogram(df_std,x='ROA')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="287e33c4-4253-4d5b-9b23-abc6eb7be17c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("287e33c4-4253-4d5b-9b23-abc6eb7be17c")) {
#                     Plotly.newPlot(
#                         '287e33c4-4253-4d5b-9b23-abc6eb7be17c',
# ...

# %%
sns.displot(df_std,x='ROE',kde=True)

# %% [markdown]
# # 匯入資料

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/mldata_standardized_with_gclass.csv')
data
# Out:
#      Unnamed: 0       ROA  ...  Total asset turnover  Growth_CLass
# 0             0  0.236765  ...             -0.791617             1
# 1             1  0.146009  ...             -0.847592             1
# 2             2  0.087351  ...             -1.258075             2
# 3             3  0.115020  ...             -0.922225             1
# 4             4  0.063002  ...             -0.250526             3
# ..          ...       ...  ...                   ...           ...
# 927         927 -0.383027  ...             -0.493084             3
# 928         928  1.793991  ...             -1.146125             1
# 929         929 -0.321048  ...             -1.108808             0
# 930         930 -0.976256  ...              0.570440             0
# 931         931  0.434877  ...             -0.511742             2
#
# [932 rows x 8 columns]

# %%
X = data[['ROA', 'ROE', 'Operating gross profit margin', 'cash flow', 'Debt ratio', 'Total asset turnover']]
y = data['Growth_CLass']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth = 200, n_estimators = 400,criterion='gini')
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=200, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=400,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print('The accuracy of Random Forest Classifier on testing set:', rfc.score(X_test, y_test))
# Out:
# The accuracy of Random Forest Classifier on testing set: 0.38197424892703863

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
parameter_space = {
    "n_estimators": [100, 15, 20],
    "criterion": ["gini", "entropy"],
    "min_samples_leaf": [200, 4, 6],
}
 
scores = ['precision', 'recall']
#scores = ['roc_auc']
 
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()
 
    clf = RandomForestClassifier(random_state=14)
    grid = GridSearchCV(clf, parameter_space, cv=5, scoring='%s_macro' % score)
    #scoring='%s_macro' % score：precision_macro、recall_macro
    grid.fit(X_train, y_train)
 
    print("Best parameters set found on development set:")
    print()
    print(grid.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = grid.cv_results_['mean_test_score']
    stds = grid.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, grid.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    bclf = grid.best_estimator_
    bclf.fit(X_train, y_train)
    y_true = y_test
    y_pred = bclf.predict(X_test)
    y_pred_pro = bclf.predict_proba(X_test)
    y_scores = pd.DataFrame(y_pred_pro, columns=bclf.classes_.tolist())[1].values
    print(classification_report(y_true, y_pred))
    #auc_value = roc_auc_score(y_true, y_scores)
# Out:
# # Tuning hyper-parameters for precision
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # 未標準化前資料

# %%
Data2 = pd.read_csv('/content/drive/MyDrive/mldata_not_yet_standardized.csv')
Data2
# Out:
#      Unnamed: 0    ID  ...  After-tax net profit growth rate  Growth_CLass
# 0             0  1101  ...                              9.96             1
# 1             1  1102  ...                            -15.60             1
# 2             2  1103  ...                             30.48             2
# 3             3  1104  ...                             10.35             1
# 4             4  1108  ...                            754.54             3
# ..          ...   ...  ...                               ...           ...
# 927         960  9944  ...                            325.81             3
# 928         961  9945  ...                             -3.24             1
# 929         962  9946  ...                            -88.48             0
# 930         963  9955  ...                          -1310.51             0
# 931         964  9958  ...                             69.45             2
#
# [932 rows x 10 columns]

# %%
Data2["cash flow"]=Data2["cash flow"].apply(clean_currency).astype('float')

# %%
X1 = Data2[['ROA', 'ROE', 'Operating gross profit margin', 'cash flow', 'Debt ratio', 'Total asset turnover']]
y1 = Data2['Growth_CLass']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.25)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth = 200, n_estimators = 400,criterion='gini')
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=200, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=400,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print('The accuracy of Random Forest Classifier on testing set:', rfc.score(X_test, y_test))
# Out:
# The accuracy of Random Forest Classifier on testing set: 0.36909871244635195

# %%
parameter_space = {
    "n_estimators": [100, 15, 20],
    "criterion": ["gini", "entropy"],
    "min_samples_leaf": [200, 4, 6],
}
 
scores = ['precision', 'recall']
#scores = ['roc_auc']
 
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()
 
    clf = RandomForestClassifier(random_state=14)
    grid = GridSearchCV(clf, parameter_space, cv=5, scoring='%s_macro' % score)
    #scoring='%s_macro' % score：precision_macro、recall_macro
    grid.fit(X_train, y_train)
 
    print("Best parameters set found on development set:")
    print()
    print(grid.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = grid.cv_results_['mean_test_score']
    stds = grid.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, grid.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    bclf = grid.best_estimator_
    bclf.fit(X_train, y_train)
    y_true = y_test
    y_pred = bclf.predict(X_test)
    y_pred_pro = bclf.predict_proba(X_test)
    y_scores = pd.DataFrame(y_pred_pro, columns=bclf.classes_.tolist())[1].values
    print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for precision
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # XGBOOST

# %%
from xgboost import XGBClassifier

# %%
X3 = data[['ROA', 'ROE', 'Operating gross profit margin', 'cash flow', 'Debt ratio', 'Total asset turnover','kMeans_labels']]
y3 = data['Growth_CLass']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X3, y3, test_size=0.25)

# %%
xgbc = XGBClassifier()
xgbc.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
print('The accuracy of eXtreme Gradient Boosting Classifier on testing set:', xgbc.score(X_test, y_test))
# Out:
# The accuracy of eXtreme Gradient Boosting Classifier on testing set: 0.4034334763948498

# %% [markdown]
# # KMEANS

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import calinski_harabaz_score
import matplotlib.pyplot as plt
sco = []
for i in range(2,15):
    kmeans = KMeans(n_clusters = i).fit(X)
    score = calinski_harabaz_score(X , kmeans.labels_)
    sco.append(score)
#     print('分%d群的calinski_harabaz分數為：%f'%(i , score))
plt.plot(range(2,15),sco)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function calinski_harabaz_score is deprecated; Function 'calinski_harabaz_score' has been renamed to 'calinski_harabasz_score' and will be removed in version 0.23.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function calinski_harabaz_score is deprecated; Function 'calinski_harabaz_score' has been renamed to 'calinski_harabasz_score' and will be removed in version 0.23.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function calinski_harabaz_score is deprecated; Function 'calinski_harabaz_score' has been renamed to 'calinski_harabasz_score' and will be removed in version 0.23.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %%
kmeans = KMeans(n_clusters=11)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=11, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_
inertia = kmeans.inertia_
data['kMeans_labels'] = labels

# %%
data['kMeans_labels'].value_counts()
# Out:
# One      235
# Nine     218
# Three    184
# Eight    183
# Zero      29
# Six       26
# Ten       25
# Four      24
# Seven      5
# Two        2
# Five       1
# Name: kMeans_labels, dtype: int64

# %%
data=data.drop(columns=['Unnamed: 0'])

# %%
for i in range(0,932):
    if data['kMeans_labels'].iloc[i]==0:
        data['kMeans_labels'].iloc[i]=0
    if data['kMeans_labels'].iloc[i]==1:
        data['kMeans_labels'].iloc[i]=1
    if data['kMeans_labels'].iloc[i]==2:
        data['kMeans_labels'].iloc[i]=2
    if data['kMeans_labels'].iloc[i]==3:
        data['kMeans_labels'].iloc[i]=3
    if data['kMeans_labels'].iloc[i]==4:
        data['kMeans_labels'].iloc[i]=4
    if data['kMeans_labels'].iloc[i]==5:
        data['kMeans_labels'].iloc[i]=5
    if data['kMeans_labels'].iloc[i]==6:
        data['kMeans_labels'].iloc[i]=6
    if data['kMeans_labels'].iloc[i]==7:
        data['kMeans_labels'].iloc[i]=7
    if data['kMeans_labels'].iloc[i]==8:
        data['kMeans_labels'].iloc[i]=8
    if data['kMeans_labels'].iloc[i]==9:
        data['kMeans_labels'].iloc[i]=9
    if data['kMeans_labels'].iloc[i]==10:
        data['kMeans_labels'].iloc[i]=10

# %%
data

# %%
data['kMeans_labels'].iloc[0]
# Out:
# 4

# %%
data.to_csv('/content/drive/MyDrive/mldata_not_yet_standardized_Kmeans.csv')

# %%
from collections import Counter
Counter(labels)
# Out:
# Counter({0: 196,
#          1: 219,
#          2: 33,
#          3: 2,
#          4: 258,
#          5: 11,
#          6: 1,
#          7: 163,
#          8: 4,
#          9: 19,
#          10: 26})

# %%
data['category'] = data['labels'].astype(str)

# %%
import plotly.express as px
fig=px.scatter_matrix(data, dimensions=['ROA', 'ROE', 'Operating gross profit margin', 'cash flow', 'Debt ratio', 'Total asset turnover'],color="category")
#fig.update_yaxes(tickangle=45, tickfont=dict(family='Rockwell', color='crimson', size=14))
#fig.update_layout({"yaxis"+str(i+1): dict(tickangle = -45) for i in range(5)})
fig.update_layout(title_font_size=1) 
#for ax in fig.ravel():
 #   ax.set_xlabel(ax.get_xlabel(), fontsize = 20, rotation = 90)
  #  ax.set_ylabel(ax.get_ylabel(), fontsize = 20, rotation = 0)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fdfb7a5e-c72f-41e7-a298-6548dfdf3a55" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fdfb7a5e-c72f-41e7-a298-6548dfdf3a55")) {
#                     Plotly.newPlot(
#                         'fdfb7a5e-c72f-41e7-a298-6548dfdf3a55',
# ...

# %%
import seaborn as sns
col = ['ROA', 'ROE', 'Operating gross profit margin', 'cash flow', 'Debt ratio', 'Total asset turnover','labels']
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
sns.pairplot(data[col],hue='labels')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning:
#
# Dataset has 0 variance; skipping density estimate.

# %%
Data = pd.read_csv('/content/drive/MyDrive/mldata_not_yet_standardized_Kmeans.csv')
Data
# Out:
#      Unnamed: 0       ROA  ...  Growth_CLass  kMeans_labels
# 0             0  0.236765  ...             1           Four
# 1             1  0.146009  ...             1           Four
# 2             2  0.087351  ...             2          Eight
# 3             3  0.115020  ...             1          Eight
# 4             4  0.063002  ...             3           Nine
# ..          ...       ...  ...           ...            ...
# 927         927 -0.383027  ...             3          Eight
# 928         928  1.793991  ...             1           Four
# 929         929 -0.321048  ...             0          Eight
# 930         930 -0.976256  ...             0          Three
# 931         931  0.434877  ...             2           Nine
#
# [932 rows x 9 columns]

# %%
Data.drop(columns=['Unnamed: 0'])
# Out:
#           ROA       ROE  ...  Growth_CLass  kMeans_labels
# 0    0.236765  0.169616  ...             1           Four
# 1    0.146009  0.118674  ...             1           Four
# 2    0.087351  0.067408  ...             2          Eight
# 3    0.115020  0.018088  ...             1          Eight
# 4    0.063002  0.069355  ...             3           Nine
# ..        ...       ...  ...           ...            ...
# 927 -0.383027 -0.152583  ...             3          Eight
# 928  1.793991  0.894483  ...             1           Four
# 929 -0.321048 -0.124030  ...             0          Eight
# 930 -0.976256 -0.458234  ...             0          Three
# 931  0.434877  0.308489  ...             2           Nine
#
# [932 rows x 8 columns]

# %%
Data[Data['kMeans_labels']=='Zero'].describe()
# Out:
#        Unnamed: 0        ROA  ...  Total asset turnover  Growth_CLass
# count   29.000000  29.000000  ...             29.000000     29.000000
# mean   473.758621   3.135282  ...              0.367772      2.517241
# std    292.553738   1.663552  ...              0.972776      0.828971
# min     26.000000   1.848223  ...             -1.332708      0.000000
# 25%    250.000000   2.062936  ...             -0.119918      2.000000
# 50%    486.000000   2.554342  ...              0.495807      3.000000
# 75%    747.000000   3.339043  ...              0.850315      3.000000
# max    914.000000   7.980839  ...              2.697488      3.000000
#
# [8 rows x 8 columns]

# %%
import plotly.express as px
px.box(Data,x='kMeans_labels', y='ROA',title='ROA')ㄍ
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cae950c7-5b40-49aa-9097-80433a167fbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cae950c7-5b40-49aa-9097-80433a167fbf")) {
#                     Plotly.newPlot(
#                         'cae950c7-5b40-49aa-9097-80433a167fbf',
# ...

# %%
px.box(Data,x='kMeans_labels', y='ROE',title='ROE')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="88934284-262f-4ee3-bb8b-59f82153cb3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88934284-262f-4ee3-bb8b-59f82153cb3c")) {
#                     Plotly.newPlot(
#                         '88934284-262f-4ee3-bb8b-59f82153cb3c',
# ...

# %%
px.box(Data,x='kMeans_labels', y='Total asset turnover',title='Total asset turnover')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ec946062-d5c2-4b3a-b2c1-260f25acec7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ec946062-d5c2-4b3a-b2c1-260f25acec7f")) {
#                     Plotly.newPlot(
#                         'ec946062-d5c2-4b3a-b2c1-260f25acec7f',
# ...

# %%
#Debt ratio
px.box(Data,x='kMeans_labels', y='Debt ratio',title='Debt ratio')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e230d954-f3ce-4510-baa3-745b17560143" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e230d954-f3ce-4510-baa3-745b17560143")) {
#                     Plotly.newPlot(
#                         'e230d954-f3ce-4510-baa3-745b17560143',
# ...

# %%
#Operating gross profit margin
px.box(Data,x='kMeans_labels', y='Operating gross profit margin',title='Operating gross profit margin')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="90117d41-2e59-47c5-8e95-84f355d7af80" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("90117d41-2e59-47c5-8e95-84f355d7af80")) {
#                     Plotly.newPlot(
#                         '90117d41-2e59-47c5-8e95-84f355d7af80',
# ...

# %%
#cash flow
px.box(Data,x='kMeans_labels', y='cash flow',title='cash flow')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="71f22bea-800a-4abd-b457-7f86c4206bfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("71f22bea-800a-4abd-b457-7f86c4206bfc")) {
#                     Plotly.newPlot(
#                         '71f22bea-800a-4abd-b457-7f86c4206bfc',
# ...

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
from sklearn import decomposition
import matplotlib.pyplot as plt
pca = decomposition.PCA(n_components=2)
#X_centered = X - X.mean(axis=0)
pca.fit(X)
X_pca = pca.transform(X)

# Plotting the results of PCA
plt.plot(X_pca[y == 0, 0], X_pca[y == 0, 1], 'bo', label='0')
plt.plot(X_pca[y == 1, 0], X_pca[y == 1, 1], 'go', label='1')
plt.plot(X_pca[y == 2, 0], X_pca[y == 2, 1], 'ro', label='2')
plt.plot(X_pca[y == 3, 0], X_pca[y == 3, 1], 'mo', label='3')

plt.legend(loc=0);

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.axis('equal');
